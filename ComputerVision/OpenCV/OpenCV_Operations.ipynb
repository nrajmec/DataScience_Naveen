# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import imutils
import cv2
from google.colab.patches import cv2_imshow

# load the input image and show its dimensions, keeping in mind that
# images are represented as a multi-dimensional NumPy array with
# shape no. rows (height) x no. columns (width) x no. channels (depth)
image = cv2.imread("/content/drive/MyDrive/Colab Notebooks/PyImageSearch/jp.jpg")
(h, w, d) = image.shape
print("width={}, height={}, depth={}".format(w, h, d))

# display the image to our screen -- we will need to click the window
# open by OpenCV and press a key on our keyboard to continue execution
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
(B, G, R) = image[100, 50]
print("R={}, G={}, B={}".format(R, G, B))
# Out:
# R=112, G=131, B=146

# %%
roi = image[60:160, 320:420]
cv2_imshow(roi)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FB9CECB82D0>
# -1

# %%
# !pip install p2j
# Out:
# Collecting p2j
#   Downloading p2j-1.3.2-py3-none-any.whl (19 kB)
# Installing collected packages: p2j
# Successfully installed p2j-1.3.2

# %%
# !p2j "/content/drive/MyDrive/Colab Notebooks/PyImageSearch/detect_faces.py"
# Out:
# Notebook /content/drive/MyDrive/Colab Notebooks/PyImageSearch/detect_faces.ipynb written.

# %%
resized = cv2.resize(image, (200, 200))
cv2_imshow(resized)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FB9CEC99590>
# -1

# %%
# fixed resizing and distort aspect ratio so let's resize the width
# to be 300px but compute the new height based on the aspect ratio
r = 300.0 / w
dim = (300, int(h * r))
resized = cv2.resize(image, dim)
cv2_imshow(resized)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=300x150 at 0x7FB9CCE1CBD0>
# -1

# %%
# manually computing the aspect ratio can be a pain so let's use the
# imutils library instead
resized = imutils.resize(image, width=500)
cv2_imshow(resized)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7FB9CED88F10>
# -1

# %%
# let's rotate an image 45 degrees clockwise using OpenCV by first
# computing the image center, then constructing the rotation matrix,
# and then finally applying the affine warp
center = (w // 2, h // 2)
M = cv2.getRotationMatrix2D(center, -45, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
cv2_imshow(rotated)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
rotated = imutils.rotate(image, -45)
cv2_imshow(rotated)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
rotated = imutils.rotate_bound(image, 45)
cv2_imshow(rotated)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# apply a Gaussian blur with a 11x11 kernel to the image to smooth it,
# useful when reducing high frequency noise
blurred = cv2.GaussianBlur(image, (33, 33), 0)
cv2_imshow(blurred)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x1000 at 0x7FB9CCE22810>
# -1

# %%
output = image.copy()
cv2.rectangle(output, (320, 60), (420, 160), (0, 0, 255), 2)
cv2_imshow(output)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# draw a blue 20px (filled in) circle on the image centered at
# x=300,y=150
output = image.copy()
cv2.circle(output, (300, 150), 20, (255, 0, 0), -1)
cv2_imshow(output)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# draw a 5px thick red line from x=60,y=20 to x=400,y=200
output = image.copy()
cv2.line(output, (60, 20), (400, 200), (0, 0, 255), 5)
cv2_imshow(output)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# draw green text on the image
output = image.copy()
cv2.putText(output, "OpenCV + Jurassic Park!!!", (10, 25), 
	cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
cv2_imshow(output)
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# import the necessary packages
import argparse
import imutils
import cv2
# construct the argument parser and parse the arguments
# ap = argparse.ArgumentParser()
# ap.add_argument("-i", "--image", required=True,
# 	help="path to input image")
# args = vars(ap.parse_args())
